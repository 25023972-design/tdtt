# %% [markdown]
# ## Bài 1

# %%
n = int(input())

print(n * 2)
# Out:
# 2

# %% [markdown]
# ## Bài 2

# %%
a = float(input())
b = float(input())

s_hcn = a * b
r = a/2
s_ht = 3.14 * (r ** 2)
s_con_lai = s_hcn - s_ht

print(f"{s_con_lai:.2f}")
# Out:
# 4.86

# %% [markdown]
# ## Bài 3

# %%
c = input()

if len(c) == 1:
    ma_ascii = ord(c)

    if 97<=ma_ascii<=122:
        chu_hoa = chr(ma_ascii - 32)
        print("chu_hoa")

    elif 65<=ma_ascii<=90:
        chu_thuong = chr(ma_ascii + 32)
        print("chu_thuong")
# Out:
# chu_hoa

# %% [markdown]
# ## Baif 4

# %%
c = input()

if len(c) == 1:
    if c.isalpha():
        print(f"c la ki tu alphabet")

    else:
        print(f"c khong phai la ki tu alphabet")
# Out:
# c la ki tu alphabet

# %% [markdown]
# ## bai 5

# %%
c = input()

if len(c) == 1 and c.isupper():
    if c == 'A':
        print("chu cai thuong lien truoc la: z")
    else:
        chu_thuong_truoc = chr(ord(c.lower()) - 1)
        print(f"{chu_thuong_truoc}")

# %% [markdown]
# ## bai 6

# %%
a = float(input())
b = float(input())
c = float(input())

if (a + b > c) and (a +c > b) and (b + c > a):
    p = (a + b + c) / 2
    dien_tich = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print(f"{dien_tich:.1f}")
else:
    print("khong phai 3 canh tam giac")
# Out:
# 2.9

# %%
a = float(input())
b = float(input())
c = float(input())

if (a + b > c) and (a + c > b) and (b + c > a):
    p = (a + b + c) / 2
    dien_tich = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print(f"{dien_tich:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# 2.9

# %% [markdown]
# ## bai 7

# %%
chuoi = input()

if len(chuoi) >= 20 and chuoi.islower:
    ki_tu_5 = chuoi[5]
    ki_tu_9 = chuoi[9]
    print(f"{ki_tu_5}")
    print(f"{ki_tu_9}")
# Out:
# y
# h

# %% [markdown]
# ## bai 8

# %%
ten_chu_ho = input()
chi_so_truoc = int(input())
chi_so_nay = int(input())

so_dien = chi_so_nay - chi_so_truoc
tien_dien = 0

if so_dien <= 50:
    tien_dien = so_dien * 1984
elif so_dien <= 100:
    tien_dien = (50 * 1984) + (so_dien - 50) * 2050
elif so_dien <= 200:
    tien_dien = (50 * 1984) + (50 * 2050) + (so_dien - 100) * 2380
elif so_dien <= 300:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (so_dien - 200) * 2998
elif so_dien <= 400:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (so_dien - 300) * 3350
else:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + (so_dien - 400) * 3460
tong_tien = round(tien_dien * 1.08)

print(f"{ten_chu_ho}")
print(f"{tong_tien}")
# Out:
# 4
# 4285
